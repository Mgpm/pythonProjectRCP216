# %%
import pandas as pd
import matplotlib.pyplot as plt
from pyspark.sql import SparkSession
from pyspark.sql import functions as fn
from pyspark.sql import types as type
from pyspark.ml.clustering import KMeans
from pyspark.ml.feature import VectorAssembler,StringIndexer,PCA,StandardScaler

from loadData import loadData
from preparationData import preparationData
from selectVar import selectVar
from dataAnalysis import dataAnalysis
from vAssembler import vAssembler
from cluster import cluster

spark = SparkSession.builder.master("local[*]").appName("ProjectRCP216").getOrCreate()

fields = [ type.StructField("var"+str(i), type.DoubleType(),True) for i in range(0,10000)]

schema = type.StructType(fields).add("label",type.StringType(),True)

loadDF = loadData(spark,schema,fn)

# %%
prepareDF = preparationData(loadDF.getDF(),fn)

# %%
prepareDF.dropDuplicates()

# %%
prepareDF.dataShape()
# Out:
# (1480, 10001)

# %%
vect = vAssembler(fn,prepareDF.getDF())

# %%
vect.vectStringIndex(StringIndexer)

# %%
vect.vectAssembler(VectorAssembler)

# %%
extractByRF = selectVar(vect.getDF(),pd,plt)

# %%
extractByRF.ModelByRandomForest()

# %%
extractByRF.featureSelect()

# %%
extractByRF.dataFeatureImportances()

# %%
extractByRF.plotFeatureImportances()

# %%
dataAn = dataAnalysis(plt,extractByRF.getDF())

# %%
dataAn.histoFunc("var1275")

# %%
vect = vAssembler(fn,dataAn.getDF())

# %%
vect.vectStringIndex(StringIndexer)

# %%
vect.vectAssembler(VectorAssembler)

# %%
dataAn.scalerStandard(StandardScaler,vect.getDF())

# %%
dataAn.vizData2D(PCA)

# %%
dataAn.getPCA().select("pcafeatures","label").show(3)
# Out:
# +--------------------+-----------+
# |         pcafeatures|      label|
# +--------------------+-----------+
# |[-1.0889898169699...|Blankenship|
# |[10.9315048834719...|      Chell|
# |[-5.0673425723174...|     Comdet|
# +--------------------+-----------+
# only showing top 3 rows

# %%
cl = cluster(KMeans,plt,dataAn.getPCA())

# %%
cl.clusterElbow(2,10)

# %%
cl.clusterPlot(5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-a5e53f2a06bd> in <module>
# ----> 1 cl.clusterPlot(5)
#
# ~/PycharmProjects/pythonProjectRCP216/cluster.py in clusterPlot(self, n)
#      33                 c2 = [col[0][1] for col in p]
#      34                 self.plt.scatter(c1,c2,s=50,c=colors[i])
# ---> 35         plt.show()
#      36
#      37
#
# NameError: name 'plt' is not defined

# %%
cl.getCluster().show()
